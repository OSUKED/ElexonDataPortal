# %%
#hide
#default_exp vis.curtailment

# %%
import pandas as pd

from ElexonDataPortal.api import Client

# %%
client = Client()
df_detsysprices = client.get_DETSYSPRICES()

df_detsysprices.head()
# Out:
# DETSYSPRICES: 100%|██████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  1.68it/s]
#              local_datetime            recordType settlementDate  \
# 0 2020-01-01 00:00:00+00:00    MAIN PRICE SUMMARY     2020-01-01
# 1 2020-01-01 00:00:00+00:00  MARKET PRICE SUMMARY     2020-01-01
# 2 2020-01-01 00:00:00+00:00                 OFFER     2020-01-01
# 3 2020-01-01 00:00:00+00:00                 OFFER     2020-01-01
# 4 2020-01-01 00:00:00+00:00                 OFFER     2020-01-01
#
#   settlementPeriod      cost   volume adjuster     value      type  \
# 0                1     51.33    1.008     0.00  50.90000  50.90000
# 1                1  27680.69  784.600      NaN  35.28000  50.90000
# 2                1       NaN      NaN      NaN       NaN       NaN
# 3                1       NaN      NaN      NaN       NaN       NaN
# 4                1       NaN      NaN      NaN       NaN       NaN
#
#   priceDerivationCode  ... nivAdjustedVolume parAdjustedvolume finalPrice  \
# 0                 NaN  ...               NaN               NaN        NaN
# 1                   P  ...               NaN               NaN        NaN
# 2                 NaN  ...            20.849             0.384   50.90000
# 3                 NaN  ...            33.488             0.616   50.90000
# 4                 NaN  ...             0.000             0.000    0.00000
#
#   transmissionLossMultiplier tlmAdjustedVolume tlmAdjustedCost  \
# 0                        NaN               NaN             NaN
# 1                        NaN               NaN             NaN
# 2                  1.0084058             0.387           19.69
# 3                  1.0084058             0.621           31.63
# 4                  0.0000000             0.000            0.00
#
#   totalOfTlmAdjustedVolume totalOfTlmAdjustedCost bidPrice bidVolume
# 0                      NaN                    NaN      NaN       NaN
# 1                      NaN                    NaN      NaN       NaN
# 2                    1.008                  51.33      NaN       NaN
# 3                    1.008                  51.33      NaN       NaN
# 4                    1.008                  51.33      NaN       NaN
#
# [5 rows x 33 columns]

# %%
df_detsysprices.iloc[3]
# Out:
# local_datetime                2020-01-01 00:00:00+00:00
# recordType                                        OFFER
# settlementDate                               2020-01-01
# settlementPeriod                                      1
# cost                                                NaN
# volume                                              NaN
# adjuster                                            NaN
# value                                               NaN
# type                                                NaN
# priceDerivationCode                                 NaN
# index                                                 2
# id                                             T_EECL-1
# acceptanceId                                     115310
# bidOfferPairId                                        1
# cadlFlag                                              F
# soFlag                                                F
# storFlag                                              F
# repricedIndicator                                     F
# reserveScarcityPrice                               NULL
# offerPrice                                     50.90000
# offerVolume                                      70.875
# dmatAdjustedVolume                               70.875
# arbitrageAdjustedVolume                          70.875
# nivAdjustedVolume                                33.488
# parAdjustedvolume                                 0.616
# finalPrice                                     50.90000
# transmissionLossMultiplier                    1.0084058
# tlmAdjustedVolume                                 0.621
# tlmAdjustedCost                                   31.63
# totalOfTlmAdjustedVolume                          1.008
# totalOfTlmAdjustedCost                            51.33
# bidPrice                                            NaN
# bidVolume                                           NaN
# Name: 3, dtype: object

# %%
#exports
flatten_list = lambda list_: [item for sublist in list_ for item in sublist]

def get_wf_ids(dictionary_url='https://raw.githubusercontent.com/OSUKED/Power-Station-Dictionary/main/data/output/power_stations.csv'):
    df_dictionary = pd.read_csv(dictionary_url)
    wf_ids = flatten_list(df_dictionary.query('fuel_type=="wind"')['sett_bmu_id'].str.split(', ').to_list())
    
    return wf_ids

# %%
wf_ids = get_wf_ids()

wf_ids[:5]
# Out:
# ['T_ACHRW-1', 'T_AKGLW-2', 'E_AIRSW-1', 'E_ASHWW-1', 'T_ANSUW-1']

# %%
#exports
def get_curtailed_wfs_df(
    api_key: str=None,
    start_date: str = '2020-01-01',
    end_date: str = '2020-01-01 1:30',
    wf_ids: list=None,
    dictionary_url: str='https://raw.githubusercontent.com/OSUKED/Power-Station-Dictionary/main/data/output/power_stations.csv'
):
    if wf_ids is None:
        wf_ids = get_wf_ids(dictionary_url=dictionary_url)
        
    if isinstance(start_date, str):
        start_date = pd.to_datetime(start_date).tz_localize('Europe/London')
        
    if isinstance(end_date, str):
        end_date = pd.to_datetime(end_date).tz_localize('Europe/London')
        
    client = Client()
    df_detsysprices = client.get_DETSYSPRICES(start_date, end_date)

    df_curtailed_wfs = (df_detsysprices
                        .query('recordType=="BID" & soFlag=="T" & id in @wf_ids')
                        .astype({'bidVolume': float})
                        .groupby(['local_datetime', 'id'])
                        ['bidVolume']
                        .sum()
                        .reset_index()
                        .pivot('local_datetime', 'id', 'bidVolume')
                       )
    
    df_curtailed_wfs = df_curtailed_wfs.reindex(pd.date_range(min(start_date, df_curtailed_wfs.index.min()), 
                                                              max(end_date-pd.Timedelta(minutes=30), df_curtailed_wfs.index.max()),
                                                              tz='Europe/London'))
    
    df_curtailed_wfs.index.name = 'local_datetime'
    
    return df_curtailed_wfs

# %%
df_curtailed_wfs = get_curtailed_wfs_df()

df_curtailed_wfs
# Out:
# DETSYSPRICES: 100%|██████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.05it/s]
# id                         T_EDINW-1
# local_datetime
# 2020-01-01 00:00:00+00:00       -5.8

# %%
curtailed_wfs_fp = '../data/curtailed_wfs.csv'
overwrite_curtailed_wfs_csv = False

if overwrite_curtailed_wfs_csv == True:
    df_curtailed_wfs.to_csv(curtailed_wfs_fp)

# %%
#exports
def load_curtailed_wfs(
    curtailed_wfs_fp: str='data/curtailed_wfs.csv'
):
    df_curtailed_wfs = pd.read_csv(curtailed_wfs_fp)

    df_curtailed_wfs = df_curtailed_wfs.set_index('local_datetime')
    df_curtailed_wfs.index = pd.to_datetime(df_curtailed_wfs.index, utc=True).tz_convert('Europe/London')
    
    return df_curtailed_wfs

# %%
df_curtailed_wfs = load_curtailed_wfs(curtailed_wfs_fp)

df_curtailed_wfs.head()
# Out:
#                            T_EDINW-1  E_BABAW-1  E_BETHW-1  E_BRYBW-1  \
# local_datetime
# 2020-01-01 00:00:00+00:00      -5.80        NaN        NaN        NaN
# 2020-01-02 00:00:00+00:00      -8.75        NaN        NaN        NaN
# 2020-01-03 00:00:00+00:00      -0.50        NaN     -9.017        NaN
# 2020-01-04 00:00:00+00:00      -3.00        NaN     -8.992        NaN
# 2020-01-05 00:00:00+00:00      -9.00        NaN        NaN        NaN
#
#                            E_BTUIW-2  E_CLFLW-1  E_HRHLW-1  E_MOYEW-1  \
# local_datetime
# 2020-01-01 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-02 00:00:00+00:00        NaN        NaN     -8.992        NaN
# 2020-01-03 00:00:00+00:00        NaN        NaN     -8.483        NaN
# 2020-01-04 00:00:00+00:00    -20.008     -3.508    -13.000        NaN
# 2020-01-05 00:00:00+00:00        NaN        NaN        NaN        NaN
#
#                            T_AKGLW-2  T_ARCHW-1  ...  E_BRDUW-1  T_RREW-1  \
# local_datetime                                   ...
# 2020-01-01 00:00:00+00:00        NaN        NaN  ...        NaN       NaN
# 2020-01-02 00:00:00+00:00        NaN    -28.467  ...        NaN       NaN
# 2020-01-03 00:00:00+00:00        NaN    -15.083  ...        NaN       NaN
# 2020-01-04 00:00:00+00:00        NaN    -48.517  ...        NaN       NaN
# 2020-01-05 00:00:00+00:00        NaN        NaN  ...        NaN       NaN
#
#                            T_BRBEO-1  T_GANW-11  T_GANW-13  T_GANW-22  \
# local_datetime
# 2020-01-01 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-02 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-03 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-04 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-05 00:00:00+00:00        NaN        NaN        NaN        NaN
#
#                            T_GANW-24  T_GRGBW-1  T_GRGBW-2  T_GRGBW-3
# local_datetime
# 2020-01-01 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-02 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-03 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-04 00:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-01-05 00:00:00+00:00        NaN        NaN        NaN        NaN
#
# [5 rows x 109 columns]

# %%
most_recent_ts = df_curtailed_wfs.index.max()

start_date = most_recent_ts + pd.Timedelta(minutes=30)
end_date = start_date + pd.Timedelta(days=7)

client = Client()
df_curtailed_wfs_wk = get_curtailed_wfs_df(start_date=start_date, end_date=end_date, wf_ids=wf_ids)

df_curtailed_wfs_wk.head()
# Out:
# DETSYSPRICES: 100%|██████████████████████████████████████████████████████████████████| 336/336 [07:32<00:00,  1.35s/it]
# id                         E_BETHW-1  E_BRDUW-1  E_BTUIW-2  E_CLDRW-1  \
# local_datetime
# 2020-12-23 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-24 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-25 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-26 22:00:00+00:00     -5.508      -27.5      -17.5      -12.5
# 2020-12-27 22:00:00+00:00        NaN        NaN        NaN        NaN
#
# id                         E_HRHLW-1  T_AKGLW-2  T_ARCHW-1  T_BHLAW-1  \
# local_datetime
# 2020-12-23 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-24 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-25 22:00:00+00:00    -11.017        NaN        NaN        NaN
# 2020-12-26 22:00:00+00:00    -13.016      -31.5    -46.533    -41.484
# 2020-12-27 22:00:00+00:00        NaN        NaN        NaN        NaN
#
# id                         T_BLLA-1  T_BLLA-2  ...  T_HRSTW-1  T_KLGLW-1  \
# local_datetime                                 ...
# 2020-12-23 22:00:00+00:00       NaN       NaN  ...        NaN        NaN
# 2020-12-24 22:00:00+00:00       NaN       NaN  ...        NaN        NaN
# 2020-12-25 22:00:00+00:00   -36.025       NaN  ...        NaN   -107.042
# 2020-12-26 22:00:00+00:00   -48.625   -27.975  ...      -62.5   -114.000
# 2020-12-27 22:00:00+00:00       NaN       NaN  ...        NaN        NaN
#
# id                         T_LCLTW-1  T_MKHLW-1  T_SANQW-1  T_STLGW-1  \
# local_datetime
# 2020-12-23 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-24 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-25 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-26 22:00:00+00:00        NaN      -17.0        NaN        NaN
# 2020-12-27 22:00:00+00:00        NaN        NaN        NaN        NaN
#
# id                         T_STLGW-2  T_STRNW-1  T_WHILW-1  T_WHILW-2
# local_datetime
# 2020-12-23 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-24 22:00:00+00:00        NaN        NaN        NaN        NaN
# 2020-12-25 22:00:00+00:00        NaN      -15.5    -18.225        NaN
# 2020-12-26 22:00:00+00:00        NaN        NaN        NaN    -72.658
# 2020-12-27 22:00:00+00:00        NaN        NaN        NaN        NaN
#
# [5 rows x 37 columns]

# %%
#exports
def add_next_week_of_data_to_curtailed_wfs(
    curtailed_wfs_fp: str='data/curtailed_wfs.csv',
    save_data: bool=True,
):
    df_curtailed_wfs = load_curtailed_wfs(curtailed_wfs_fp)
    most_recent_ts = df_curtailed_wfs.index.max()

    start_date = most_recent_ts + pd.Timedelta(minutes=30)
    end_date = start_date + pd.Timedelta(days=7)

    client = Client()
    df_curtailed_wfs_wk = get_curtailed_wfs_df(start_date=start_date, end_date=end_date, wf_ids=wf_ids)

    df_curtailed_wfs = df_curtailed_wfs.append(df_curtailed_wfs_wk)    
    df_curtailed_wfs.to_csv(curtailed_wfs_fp)
    
    return df_curtailed_wfs

# %%
df_curtailed_wfs = add_next_week_of_data_to_curtailed_wfs('../data/curtailed_wfs.csv')
# Out:
# DETSYSPRICES: 100%|██████████████████████████████████████████████████████████████████| 336/336 [06:31<00:00,  1.17s/it]

# %%
reached_latest_wk = False
update_freq = 5
update_counter = 1
df_curtailed_wfs = load_curtailed_wfs(curtailed_wfs_fp)

while reached_latest_wk == False:
    df_curtailed_wfs = add_next_week_of_data_to_curtailed_wfs('../data/curtailed_wfs.csv')

    most_recent_ts = df_curtailed_wfs.index.max()
    reached_latest_wk = (pd.Timestamp.now(tz='Europe/London') - most_recent_ts).total_seconds() <= 60*60*24*7

    if update_counter == update_freq:
        update_counter = 1
        print(f"Have now reached: {most_recent_ts.strftime('%Y-%m-%d %H:%M')}")
    else:
        update_counter += 1
# Out:
# DETSYSPRICES:  90%|███████████████████████████████████████████████████████████▏      | 301/336 [06:07<00:42,  1.22s/it]
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\envs\BMRS\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# --> 953     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001E2D99D68E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\envs\BMRS\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.bmreports.com', port=443): Max retries exceeded with url: /BMRS/DETSYSPRICES/v1?APIKey=pqth1yrw1rkh5eb&SettlementDate=2021-01-05&SettlementPeriod=11&ServiceType=xml (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001E2D99D68E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-15-0778840fe038> in <module>
#       5
#       6 while reached_latest_wk == False:
# ----> 7     df_curtailed_wfs = add_next_week_of_data_to_curtailed_wfs('../data/curtailed_wfs.csv')
#       8
#       9     most_recent_ts = df_curtailed_wfs.index.max()
#
# <ipython-input-13-9e3abccc717f> in add_next_week_of_data_to_curtailed_wfs(curtailed_wfs_fp, save_data)
#      11
#      12     client = Client()
# ---> 13     df_curtailed_wfs_wk = get_curtailed_wfs_df(start_date=start_date, end_date=end_date, wf_ids=wf_ids)
#      14
#      15     df_curtailed_wfs = df_curtailed_wfs.append(df_curtailed_wfs_wk)
#
# <ipython-input-7-8a3d7251f756> in get_curtailed_wfs_df(api_key, start_date, end_date, wf_ids, dictionary_url)
#      17
#      18     client = Client()
# ---> 19     df_detsysprices = client.get_DETSYSPRICES(start_date, end_date)
#      20
#      21     df_curtailed_wfs = (df_detsysprices
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\api.py in get_DETSYSPRICES(self, start_date, end_date)
#    1082         """
#    1083
# -> 1084         df = orchestrator.query_orchestrator(
#    1085             method='get_DETSYSPRICES',
#    1086             api_key=self.api_key,
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\dev\orchestrator.py in query_orchestrator(method, api_key, request_type, kwargs_map, func_params, start_date, end_date, n_attempts, **kwargs)
#     409     request_func = request_type_to_func[request_type]
#     410
# --> 411     df = request_func(
#     412         method=method,
#     413         api_key=api_key,
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\dev\orchestrator.py in SP_and_date_request(method, kwargs_map, func_params, api_key, start_date, end_date, n_attempts, **kwargs)
#      75         assert len(missing_kwargs) == 0, f"The following kwargs are missing: {', '.join(missing_kwargs)}"
#      76
# ---> 77         r = retry_request(raw, method, kwargs, n_attempts=n_attempts)
#      78
#      79         df_SP = utils.parse_xml_response(r)
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\dev\orchestrator.py in retry_request(raw, method, kwargs, n_attempts)
#      27             attempts += 1
#      28             if attempts == n_attempts:
# ---> 29                 raise e
#      30
#      31     return r
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\dev\orchestrator.py in retry_request(raw, method, kwargs, n_attempts)
#      21     while (attempts < n_attempts) and (success == False):
#      22         try:
# ---> 23             r = getattr(raw, method)(**kwargs)
#      24             utils.check_status(r)
#      25             success = True
#
# c:\users\ayrto\desktop\phd\data\bmrs\elexon-bmrs-api-wrapper\ElexonDataPortal\dev\raw.py in get_DETSYSPRICES(APIKey, SettlementDate, SettlementPeriod, ServiceType, endpoint)
#     895     }
#     896
# --> 897     r = requests.get(endpoint, params=params)
#     898
#     899     return r
#
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\BMRS\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.bmreports.com', port=443): Max retries exceeded with url: /BMRS/DETSYSPRICES/v1?APIKey=pqth1yrw1rkh5eb&SettlementDate=2021-01-05&SettlementPeriod=11&ServiceType=xml (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001E2D99D68E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
# want to plot a map of total curtailment in the last year
# want to plot an aggregated time-series of the last year
# if there has been curtailment in the last week then should show it in full
# want to report total curtailment to date on an annual basis

# %%
df_curtailed_wfs = load_curtailed_wfs(curtailed_wfs_fp)
(-df_curtailed_wfs.sum(axis=1)).plot()

# %%
(-df_curtailed_wfs.sum(axis=1)).plot()

# %%
# def update_curtailed_wfs_data():
start_date = df_curtailed_wfs.index.max()
end_date = (pd.Timestamp.now(tz='Europe/London') + pd.Timedelta(minutes=60)).round('60min')

client = Client()
df_detsysprices = client.get_DETSYSPRICES(start_date=start_date, end_date=end_date)

df_detsysprices.head()
